# %%
'''Ejercicio 3.6.1.
Dado el documento, Esculturas_Parque_Arqueolgicos_Colombia.csv, cárgalo en un dataframe.'''

import pandas as pd

path = r'/Users/okashi/Desktop/Esculturas_Parque_Arqueolgicos_Colombia.csv'

df_esculturas = pd.read_csv(path, sep=',')

df_esculturas
# Out:
#     Parque Arqueologico Elemento arqueológico  \
# 0           San Agustín             escultura
# 1           San Agustín             escultura
# 2           San Agustín             escultura
# 3           San Agustín             escultura
# 4           San Agustín             escultura
# ..                  ...                   ...
# 207      Ciudad Perdida     Anillo de terraza
# 208      Ciudad Perdida       Muro de terraza
# 209      Ciudad Perdida       Muro de terraza
# 210      Ciudad Perdida         Unidad Visual
# 211      Ciudad Perdida         Unidad Visual
#
#                       Nombre elemento arqueológico              Código ICANH  \
# 0                      Figura masculina sin rostro                  No.  380
# 1    Figura masculina con una cara sobre el cuerpo                    No. 24
# 2                         Figura con una serpiente                    No. 40
# 3                                Guardián de tumba                    No. 65
# ...

# %%
'''Ejercicio 3.6.2.
Muestra, los datos del registro cuyo índice es 105. ¿Cuál es el nombre del elemento buscado?'''

print(df_esculturas.iloc[105],'\n')
print('El índice 105 es:',df_esculturas.iloc[105]['Nombre elemento arqueológico'])
# Out:
# Parque Arqueologico                                                         San Agustín
# Elemento arqueológico                                                         escultura
# Nombre elemento arqueológico                              Personaje con collar y tocado
# Código ICANH                                                                     No.179
# Descripción                           Personaje con cara redondeada, ojos medianos a...
# Ubicación actual dentro del parque                                   Museo arqueológico
# Datos historicos                      Procede del sitio denominado El Tablón. “Poste...
# Dimensiones visibles                                                 77cm x 44cm x 26cm
# Técnica de elaboración                         Piedra tallada, de superficie homogénea.
# Datos bibliograficos                  Sotomayor María Lucia, Uribe Maria Victoria. E...
# Name: 105, dtype: object
#
# El índice 105 es: Personaje con collar y tocado

# %%
'''Ejercicio 3.6.3.
Muestra el nombre y la ubicación de los registros cuyos índices son 24, 36, 125 y 182. 
¿Alguno de los elementos está en la misma ubicación?'''

df_esculturas.iloc[[24,36,125,182],[2,5]]
# Out:
#                   Nombre elemento arqueológico  \
# 24   Columna en piedra con una cara en relieve
# 36                        Un mono con un niño.
# 125            Figura con pescado en las manos
# 182                                    hipogeo
#
#                Ubicación actual dentro del parque
# 24                         Bosque de las estatuas
# 36                         Bosque de las estatuas
# 125  Meseta A, Montículo VIII, Alto de los Idolos
# 182                               Alto del Duende

# %% [markdown]
# Los índices 24 y 36 tienen la misma ubicación.

# %%
'''Ejercicio 3.6.4.
Muestra el código ICANH de los registros con índices entre el 100 y 110'''

df_esculturas.iloc[100:111,[3]]
# Out:
#     Código ICANH
# 100       No 133
# 101       No.138
# 102      No 155A
# 103       No.168
# 104       No.173
# 105       No.179
# 106      No. 483
# 107       No.213
# 108       No.234
# 109       No.369
# 110        No.41

# %%
'''Ejercicio 3.6.5.
Utilizando el mismo dataframe, muestra solo los registros cuyo índice es impar. ¿Cuántas registros habría?'''

df_esculturas.iloc[lambda x: x.index % 2!= 0]
# Out:
#     Parque Arqueologico Elemento arqueológico  \
# 1           San Agustín             escultura
# 3           San Agustín             escultura
# 5           San Agustín             escultura
# 7           San Agustín             escultura
# 9           San Agustín             escultura
# ..                  ...                   ...
# 203      Ciudad Perdida     Anillo de terraza
# 205      Ciudad Perdida     Anillo de terraza
# 207      Ciudad Perdida     Anillo de terraza
# 209      Ciudad Perdida       Muro de terraza
# 211      Ciudad Perdida         Unidad Visual
#
#                       Nombre elemento arqueológico              Código ICANH  \
# 1    Figura masculina con una cara sobre el cuerpo                    No. 24
# 3                                Guardián de tumba                    No. 65
# 5                                Guardián de tumba                    No. 72
# 7                                Guardián de tumba                     No.75
# ...

# %%
'''Ejercicio 3.6.6.
Utilizando el mismo dataframe, muestra la ubicación actual de los registros cuyo índice tenga como valores 10, 20, 30, 40 y 50.'''

df_esculturas.iloc[[10,20,30,40,50],[5]]
# Out:
#    Ubicación actual dentro del parque
# 10             Bosque de las estatuas
# 20             Bosque de las estatuas
# 30             Bosque de las estatuas
# 40                           Mesita A
# 50    Montículo occidental.  Mesita A

# %%
'''Ejercicio 3.6.7.
Crea un nuevo dataframe basado en el anterior, pero cuyo índice sea Elemento arqueológico'''

df2 = df_esculturas.set_index('Elemento arqueológico')
df2
# Out:
#                       Parque Arqueologico  \
# Elemento arqueológico
# escultura                     San Agustín
# escultura                     San Agustín
# escultura                     San Agustín
# escultura                     San Agustín
# escultura                     San Agustín
# ...                                   ...
# Anillo de terraza          Ciudad Perdida
# Muro de terraza            Ciudad Perdida
# Muro de terraza            Ciudad Perdida
# Unidad Visual              Ciudad Perdida
# Unidad Visual              Ciudad Perdida
#
#                                         Nombre elemento arqueológico  \
# Elemento arqueológico
# escultura                                Figura masculina sin rostro
# escultura              Figura masculina con una cara sobre el cuerpo
# escultura                                   Figura con una serpiente
# escultura                                          Guardián de tumba
# ...

# %%
'''Ejercicio 3.6.8.
Del nuevo dataframe creado muestra todos los elementos que tienen un índice disto a escultura. ¿Cuántos elementos hay?'''

filtro1 = df2.loc[lambda x: x.index != 'escultura']


print('Número de elementos:',filtro1.shape[0])
filtro1
# Out:
# Número de elementos: 88
#                       Parque Arqueologico  \
# Elemento arqueológico
# Sarcófago                     San Agustín
# laja                          San Agustín
# laja                          San Agustín
# laja                          San Agustín
# estela                        San Agustín
# ...                                   ...
# Anillo de terraza          Ciudad Perdida
# Muro de terraza            Ciudad Perdida
# Muro de terraza            Ciudad Perdida
# Unidad Visual              Ciudad Perdida
# Unidad Visual              Ciudad Perdida
#
#                                             Nombre elemento arqueológico  \
# Elemento arqueológico
# Sarcófago                                                      Sarcófago
# laja                            Laja con representación de figura humana
# laja                                        Laja con rostro antropomorfo
# laja                   Relieve de  una figura femenina  que enseña un...
# ...

# %%
'''Ejercicio 3.6.9.
Del nuevo dataframe muestra todos los elementos cuyo índice es Sarcófago. ¿Cuántos elementos hay?'''

filtro2 = df2.loc[lambda x: x.index == 'Sarcófago']

print('Número de elementos:',filtro2.shape[0])
filtro2
# Out:
# Número de elementos: 5
#                       Parque Arqueologico  \
# Elemento arqueológico
# Sarcófago                     San Agustín
# Sarcófago                     San Agustín
# Sarcófago              Alto de los Idolos
# Sarcófago              Alto de los Idolos
# Sarcófago              Alto de los Idolos
#
#                                      Nombre elemento arqueológico  \
# Elemento arqueológico
# Sarcófago                                               Sarcófago
# Sarcófago                                               Sarcófago
# Sarcófago                                               Sarcófago
# Sarcófago               Sarcófago monolítico con dos agarraderas.
# Sarcófago              Sarcófago monolítico con tapa y vertedera.
#
#                       Código ICANH  \
# Elemento arqueológico
# Sarcófago                      S-2
# Sarcófago                      S-1
# Sarcófago                      S-3
# Sarcófago                      S-4
# ...

# %%
'''Ejercicio 3.6.10.
Convierte el resultado del ejercicio anterior en un nuevo dataframe, reinicia su índice y muestra el Parque Arqueologico de los 3 primeros elementos'''
import pandas

df3 = df2.loc[lambda x: x.index == 'Sarcófago'].copy()
df3 = df3.reset_index()
df3.iloc[0:3,[1]]
# Out:
#   Parque Arqueologico
# 0         San Agustín
# 1         San Agustín
# 2  Alto de los Idolos

# %%
'''Ejercicio 3.7.1.
Dado el documento, ejecucion-presupuestaria_Chile-febrero-2023.csv'''

import pandas as pd

path = r'/Users/okashi/Desktop/ejecucion-presupuestaria_Chile-febrero-2023.csv'

df_presupuestos = pd.read_csv(path, sep=';')

df_presupuestos
# Out:
#      Año      Mes   Moneda  Subtítulo  \
# 0   2023  Febrero  DOLARES          1
# 1   2023  Febrero  DOLARES          6
# 2   2023  Febrero  DOLARES          7
# 3   2023  Febrero  DOLARES          8
# 4   2023  Febrero  DOLARES         11
# 5   2023  Febrero  DOLARES         12
# 6   2023  Febrero  DOLARES         21
# 7   2023  Febrero  DOLARES         22
# 8   2023  Febrero  DOLARES         23
# 9   2023  Febrero  DOLARES         24
# 10  2023  Febrero  DOLARES         25
# 11  2023  Febrero  DOLARES         29
# 12  2023  Febrero  DOLARES         30
# 13  2023  Febrero  DOLARES         31
# 14  2023  Febrero  DOLARES         32
# 15  2023  Febrero  DOLARES         34
# 16  2023  Febrero    PESOS          1
# 17  2023  Febrero    PESOS          4
# 18  2023  Febrero    PESOS          5
# 19  2023  Febrero    PESOS          6
# 20  2023  Febrero    PESOS          7
# 21  2023  Febrero    PESOS          8
# 22  2023  Febrero    PESOS          9
# ...

# %%
'''Ejercicio 3.7.2.
muestra las columnas Nombre_Subtítulo y Ejecución_de_FEBRERO'''

df_presupuestos[['Nombre_Subtítulo','Ejecución_de_FEBRERO']]
# Out:
#                            Nombre_Subtítulo  Ejecución_de_FEBRERO
# 0                                 IMPUESTOS                 15844
# 1                    RENTAS DE LA PROPIEDAD                 27215
# 2                     INGRESOS DE OPERACIÓN                   230
# 3                 OTROS INGRESOS CORRIENTES                238527
# 4              VENTA DE ACTIVOS FINANCIEROS               -388279
# 5                 RECUPERACIÓN DE PRÉSTAMOS                    78
# 6                        GASTOS EN PERSONAL                  8703
# 7             BIENES Y SERVICIOS DE CONSUMO                 20441
# 8          PRESTACIONES DE SEGURIDAD SOCIAL                     7
# 9                 TRANSFERENCIAS CORRIENTES                   699
# 10                        INTEGROS AL FISCO                     0
# 11    ADQUISICIÓN DE ACTIVOS NO FINANCIEROS                    33
# 12       ADQUISICIÓN DE ACTIVOS FINANCIEROS               -188426
# ...

# %%
'''Ejercicio 3.7.3.
muestra los registros cuya ejecución de febrero haya sido menor o igual que 0. Utiliza un condicional simple para realizar la consulta'''

df_presupuestos[df_presupuestos['Ejecución_de_FEBRERO']<=0]
# Out:
#      Año      Mes   Moneda  Subtítulo  \
# 4   2023  Febrero  DOLARES         11
# 10  2023  Febrero  DOLARES         25
# 12  2023  Febrero  DOLARES         30
# 13  2023  Febrero  DOLARES         31
# 35  2023  Febrero    PESOS         28
#
#                            Nombre_Subtítulo  Ejecución_de_FEBRERO  \
# 4              VENTA DE ACTIVOS FINANCIEROS               -388279
# 10                        INTEGROS AL FISCO                     0
# 12       ADQUISICIÓN DE ACTIVOS FINANCIEROS               -188426
# 13                 INICIATIVAS DE INVERSIÓN                     0
# 35  APORTE FISCAL PARA SERVICIO DE LA DEUDA                     0
#
#     Ejecución_a_FEBRERO
# 4                925253
# 10                  116
# 12               785800
# 13                    4
# 35               138641

# %%
'''Ejercicio 3.7.4.
Realiza, de nuevo, la consulta del ejercicio 3.7.3 pero, esta vez, muestra solo el Nombre_Subtítulo y la Ejecución_de_FEBRERO'''

df_presupuestos.loc[df_presupuestos['Ejecución_de_FEBRERO']<=0,['Nombre_Subtítulo','Ejecución_de_FEBRERO']]
# Out:
#                            Nombre_Subtítulo  Ejecución_de_FEBRERO
# 4              VENTA DE ACTIVOS FINANCIEROS               -388279
# 10                        INTEGROS AL FISCO                     0
# 12       ADQUISICIÓN DE ACTIVOS FINANCIEROS               -188426
# 13                 INICIATIVAS DE INVERSIÓN                     0
# 35  APORTE FISCAL PARA SERVICIO DE LA DEUDA                     0

# %%
'''Ejercicio 3.7.5.
Utilizando el mismo dataframe, muestra los registros cuya ejecución de febrero sea mayor de 20000 DOLARES'''

df_presupuestos[(df_presupuestos['Ejecución_de_FEBRERO']>20000)&(df_presupuestos['Moneda']=='DOLARES')]
# Out:
#      Año      Mes   Moneda  Subtítulo               Nombre_Subtítulo  \
# 1   2023  Febrero  DOLARES          6         RENTAS DE LA PROPIEDAD
# 3   2023  Febrero  DOLARES          8      OTROS INGRESOS CORRIENTES
# 7   2023  Febrero  DOLARES         22  BIENES Y SERVICIOS DE CONSUMO
# 15  2023  Febrero  DOLARES         34           SERVICIO DE LA DEUDA
#
#     Ejecución_de_FEBRERO  Ejecución_a_FEBRERO
# 1                  27215                62850
# 3                 238527               239760
# 7                  20441                25054
# 15                 36240               379109

# %%
'''Ejercicio 3.7.6.
Muestra ahora, del mismo dataframe, los Subtítulos y la Ejecución_a_FEBRERO de los registros cuya ejecución a febrero haya sido mayor que 10000000 de PESOS.'''

df_presupuestos.loc[(df_presupuestos['Ejecución_a_FEBRERO']>10000000)&(df_presupuestos['Moneda']=='PESOS'),['Subtítulo','Ejecución_a_FEBRERO']]
# Out:
#     Subtítulo  Ejecución_a_FEBRERO
# 16          1           9534921798
# 17          4            566922220
# 19          6           1039601756
# 20          7            223880388
# 21          8            558446654
# 24         11           1861934948
# 25         12           1088434258
# 26         13             16164561
# 27         14           3442520900
# 28         21           2095259467
# 29         22            666083207
# 30         23           2143056664
# 31         24           3672236118
# 32         25             79620638
# 33         26             32781117
# 34         27             22172356
# 36         29             13422080
# 37         30           5741252185
# 38         31             88474644
# 39         32            152643300
# 40         33            532807908
# 41         34           2646331382

# %%
'''Ejercicio 3.7.7.
Dada la lista ["IMPUESTOS","RENTAS DE LA PROPIEDAD","INGRESOS DE OPERACIÓN","VENTA DE ACTIVOS FINANCIEROS"]
y utilizando el dataframe anterior, muestra los registros cuyo nombre de subtítulo coincida con alguno de los elementos de la lista'''


import pandas as pd

path = r'/Users/okashi/Desktop/ejecucion-presupuestaria_Chile-febrero-2023.csv'

df_presupuestos = pd.read_csv(path, sep=';')
lista = ["IMPUESTOS","RENTAS DE LA PROPIEDAD","INGRESOS DE OPERACIÓN","VENTA DE ACTIVOS FINANCIEROS"]

df_presupuestos.loc[df_presupuestos['Nombre_Subtítulo'].isin(lista)]
# Out:
#      Año      Mes   Moneda  Subtítulo              Nombre_Subtítulo  \
# 0   2023  Febrero  DOLARES          1                     IMPUESTOS
# 1   2023  Febrero  DOLARES          6        RENTAS DE LA PROPIEDAD
# 2   2023  Febrero  DOLARES          7         INGRESOS DE OPERACIÓN
# 4   2023  Febrero  DOLARES         11  VENTA DE ACTIVOS FINANCIEROS
# 16  2023  Febrero    PESOS          1                     IMPUESTOS
# 19  2023  Febrero    PESOS          6        RENTAS DE LA PROPIEDAD
# 20  2023  Febrero    PESOS          7         INGRESOS DE OPERACIÓN
# 24  2023  Febrero    PESOS         11  VENTA DE ACTIVOS FINANCIEROS
#
#     Ejecución_de_FEBRERO  Ejecución_a_FEBRERO
# 0                  15844                39642
# 1                  27215                62850
# 2                    230                  477
# 4                -388279               925253
# 16            4096501621           9534921798
# 19              26173541           1039601756
# ...

# %%
'''Ejercicio 3.7.8.
Muestra ahora solo los registros cuya ejecución de febrero sea mayor de 10000 DOLARES 
y cuyo nombre de subtítulo coincida con alguno de los elementos de la lista proporcionada en el ejercicio 3.7.7'''

lista = ["IMPUESTOS","RENTAS DE LA PROPIEDAD","INGRESOS DE OPERACIÓN","VENTA DE ACTIVOS FINANCIEROS"]

df_presupuestos.loc[(df_presupuestos['Ejecución_de_FEBRERO']>10000)&
                    (df_presupuestos['Nombre_Subtítulo'].isin(lista))
                    &(df_presupuestos['Moneda']=='DOLARES')]
# Out:
#     Año      Mes   Moneda  Subtítulo        Nombre_Subtítulo  \
# 0  2023  Febrero  DOLARES          1               IMPUESTOS
# 1  2023  Febrero  DOLARES          6  RENTAS DE LA PROPIEDAD
#
#    Ejecución_de_FEBRERO  Ejecución_a_FEBRERO
# 0                 15844                39642
# 1                 27215                62850

# %%
'''Ejercicio 3.7.9.
muestra los registros en los que la diferencia entre la Ejecución_a_FEBRERO menos la Ejecución_de_FEBRERO sea igual a 0'''

import pandas as pd

path = r'/Users/okashi/Desktop/ejecucion-presupuestaria_Chile-febrero-2023.csv'

df_presupuestos = pd.read_csv(path, sep=';')

df_presupuestos[df_presupuestos['Ejecución_a_FEBRERO']-df_presupuestos['Ejecución_de_FEBRERO']==0]
# Out:
#      Año      Mes   Moneda  Subtítulo                  Nombre_Subtítulo  \
# 8   2023  Febrero  DOLARES         23  PRESTACIONES DE SEGURIDAD SOCIAL
# 22  2023  Febrero    PESOS          9                     APORTE FISCAL
# 27  2023  Febrero    PESOS         14                     ENDEUDAMIENTO
#
#     Ejecución_de_FEBRERO  Ejecución_a_FEBRERO
# 8                      7                    7
# 22                489240               489240
# 27            3442520900           3442520900

# %%
'''Ejercicio 3.7.10.
Muestra ahora los registros cuya diferencia entre la Ejecución_a_FEBRERO menos la Ejecución_de_FEBRERO sea mayor que 250000 DOLARES.'''

df_presupuestos[(df_presupuestos['Ejecución_a_FEBRERO']-df_presupuestos['Ejecución_de_FEBRERO']>250000)
                    & (df_presupuestos['Moneda']== 'DOLARES')]
# Out:
#      Año      Mes   Moneda  Subtítulo                    Nombre_Subtítulo  \
# 4   2023  Febrero  DOLARES         11        VENTA DE ACTIVOS FINANCIEROS
# 12  2023  Febrero  DOLARES         30  ADQUISICIÓN DE ACTIVOS FINANCIEROS
# 15  2023  Febrero  DOLARES         34                SERVICIO DE LA DEUDA
#
#     Ejecución_de_FEBRERO  Ejecución_a_FEBRERO
# 4                -388279               925253
# 12               -188426               785800
# 15                 36240               379109
